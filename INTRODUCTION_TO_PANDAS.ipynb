# %% [markdown]
# <a href="https://colab.research.google.com/github/TuragaMurali29/Introduction-To-Pandas/blob/main/INTRODUCTION_TO_PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# upload a csv file
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-2a097524-2710-483d-9edd-0038ce2e9274" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a097524-2710-483d-9edd-0038ce2e9274">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive # import the drive module from google.colab
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Copy of Credit_Card_Applications.csv'  )

# %%
dataset
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
dataset.info
# Out:
# <bound method DataFrame.info of      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
# ...

# %%
dataset.loc[0,'A7']
# Out:
# 1.585

# %%
dataset.tail(10) # Replace ds with dataset
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 680    15790689   1  21.17   0.000   2   8   4  0.500   0   0    0    1    1
# 681    15665181   1  35.25  16.500   1   8   4  4.000   1   0    0    0    2
# 682    15633608   0  22.92  11.585   2  13   4  0.040   1   0    0    0    2
# 683    15805261   0  48.17   1.335   2   3   7  0.335   0   0    0    0    2
# 684    15740356   1  43.00   0.290   1  13   8  1.750   1   1    8    0    2
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 680    0     1      0
# 681   80     1      0
# 682   80  1350      1
# 683    0   121      0
# ...

# %%
pd.set_option('display.max_columns',50)
pd.set_option('display.max_rows',50)

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))

  idata = {'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [20,
#   79,
#   86,
#   8,
#   16,
#   47,
#   1,
#   1,
#   100,
#   42,
#   37,
#   13,
#   53,
#   29,
#   16,
#   39,
#   47,
#   50,
#   38,
#   68,
#   77,
#   53,
#   23,
#   44,
#   31,
#   54,
#   64,
#   18,
#   80,
#   19,
#   46,
#   88,
#   70,
#   26,
#   5,
#   9,
#   29,
#   31,
#   2,
#   13,
#   26,
#   84,
#   9,
#   61,
#   57,
#   58,
#   39,
#   74,
#   30,
#   50,
#   89,
#   21,
#   33,
#   34,
#   43,
#   24,
#   26,
#   42,
#   1,
#   99,
#   63,
#   89,
#   70,
#   35,
#   90,
#   70,
#   26,
#   84,
#   36,
#   39,
#   23,
#   13,
#   12,
#   37,
#   16,
#   20,
#   84,
#   17,
#   18,
#   1,
#   78,
#   53,
#   88,
#   68,
#   6,
#   37,
#   9,
#   74,
#   9,
#   92,
#   24,
#   5,
#   96,
#   99,
#   8,
#   9,
#   97,
#   21,
#   54,
#   70],
#  'Height': [25,
#   58,
#   62,
#   90,
#   26,
#   94,
#   1,
#   73,
#   15,
#   98,
#   18,
#   57,
#   63,
#   15,
#   68,
#   55,
#   9,
#   49,
#   16,
#   77,
#   21,
#   98,
#   77,
#   20,
# ...

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    20      25      33     33
# 1    79      58      44      7
# 2    86      62      13     87
# 3     8      90      75     78
# 4    16      26       5      6
# ..  ...     ...     ...    ...
# 95    9      97      16     96
# 96   97      66      14     86
# 97   21      93      48     71
# 98   54      80      43     94
# 99   70      92      11     95
#
# [100 rows x 4 columns]

# %%
df1.tail(10)
# Out:
#     Age  Height  Weight  Speed
# 90   24      45      41     22
# 91    5      60     100     65
# 92   96      10      81     37
# 93   99      13      53     19
# 94    8      89      72     71
# 95    9      97      16     96
# 96   97      66      14     86
# 97   21      93      48     71
# 98   54      80      43     94
# 99   70      92      11     95

# %%
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    43.120000   51.320000   44.030000   48.620000
# std     29.134755   30.592427   28.112492   30.136652
# min      1.000000    1.000000    0.000000    0.000000
# 25%     18.750000   25.750000   17.750000   21.000000
# 50%     37.500000   55.000000   43.000000   49.000000
# 75%     68.500000   78.500000   66.000000   73.500000
# max    100.000000  100.000000  100.000000  100.000000

# %%
df1['Age']
# Out:
# 0     20
# 1     79
# 2     86
# 3      8
# 4     16
#       ..
# 95     9
# 96    97
# 97    21
# 98    54
# 99    70
# Name: Age, Length: 100, dtype: int64

# %%
df1.loc[[0,3],['Age','Weight']]
# Out:
#    Age  Weight
# 0   20      33
# 3    8      75

# %%
df2 = df1 [['Age','Weight']]

# %%
df2
# Out:
#     Age  Weight
# 0    20      33
# 1    79      44
# 2    86      13
# 3     8      75
# 4    16       5
# ..  ...     ...
# 95    9      16
# 96   97      14
# 97   21      48
# 98   54      43
# 99   70      11
#
# [100 rows x 2 columns]

# %%
df2.sort_index(ascending=False)
# Out:
#     Age  Weight
# 99   70      11
# 98   54      43
# 97   21      48
# 96   97      14
# 95    9      16
# ..  ...     ...
# 4    16       5
# 3     8      75
# 2    86      13
# 1    79      44
# 0    20      33
#
# [100 rows x 2 columns]

# %%
#slicing method
df1[0::2]
# Out:
#     Age  Height  Weight  Speed
# 0    20      25      33     33
# 2    86      62      13     87
# 4    16      26       5      6
# 6     1       1      38     50
# 8   100      15      66     87
# 10   37      18      80     57
# 12   53      63      79     21
# 14   16      68      35     94
# 16   47       9      51     86
# 18   38      16      33     72
# 20   77      21      39     47
# 22   23      77      32     86
# 24   31      84       2     62
# 26   64      73      62      9
# 28   80      62      40     58
# 30   46       3      57     66
# 32   70      68       9     12
# 34    5      72      24     10
# 36   29      21      23     52
# 38    2      31       9     38
# 40   26       7      66     49
# 42    9      91      49     61
# 44   57      48      35     18
# 46   39      55      28     16
# 48   30       9      69     20
# 50   89      17      77     72
# 52   33       9       7     80
# 54   43      76      12      6
# 56   26      99      88     28
# ...

# %%
df1[0::2].describe()
# Out:
#               Age      Height      Weight       Speed
# count   50.000000   50.000000   50.000000   50.000000
# mean    42.020000   46.680000   43.580000   52.640000
# std     30.330486   29.674039   27.262211   30.348829
# min      1.000000    1.000000    2.000000    0.000000
# 25%     16.500000   18.750000   20.750000   23.250000
# 50%     34.500000   47.500000   40.500000   55.000000
# 75%     68.500000   71.000000   63.500000   81.500000
# max    100.000000  100.000000  100.000000  100.000000

# %%
#filter-with conditional operaters
filter1 = df1['Weight'] > 50

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 3     8      90      75     78
# 5    47      94      61     50
# 7     1      73      84     89
# 8   100      15      66     87
# 10   37      18      80     57
# 12   53      63      79     21
# 13   29      15      96     19
# 16   47       9      51     86
# 17   50      49      94     95
# 19   68      77      74      4
# 23   44      20      62     36
# 25   54      88      81     28
# 26   64      73      62      9
# 30   46       3      57     66
# 39   13       5      75      2
# 40   26       7      66     49
# 43   61      40      82     68
# 45   58      66      71     30
# 48   30       9      69     20
# 49   50      80      95     44
# 50   89      17      77     72
# 56   26      99      88     28
# 58    1     100      56     82
# 64   90      13      90     24
# 65   70      33      67     48
# 66   26      62      57     94
# 68   36      39      57     96
# 71   13      26      63     21
# 73   37      29      52     92
# ...

# %%
filter2 = df1['Age'] > 40

# %%
df1.loc[filter1 & filter2]
# Out:
#     Age  Height  Weight  Speed
# 5    47      94      61     50
# 8   100      15      66     87
# 12   53      63      79     21
# 16   47       9      51     86
# 17   50      49      94     95
# 19   68      77      74      4
# 23   44      20      62     36
# 25   54      88      81     28
# 26   64      73      62      9
# 30   46       3      57     66
# 43   61      40      82     68
# 45   58      66      71     30
# 49   50      80      95     44
# 50   89      17      77     72
# 64   90      13      90     24
# 65   70      33      67     48
# 80   78       3     100     99
# 82   88      45      56     57
# 83   68      82      73     61
# 89   92       4      67     33
# 92   96      10      81     37
# 93   99      13      53     19

# %%
df1.loc[filter1 | filter2]
# Out:
#     Age  Height  Weight  Speed
# 1    79      58      44      7
# 2    86      62      13     87
# 3     8      90      75     78
# 5    47      94      61     50
# 7     1      73      84     89
# ..  ...     ...     ...    ...
# 93   99      13      53     19
# 94    8      89      72     71
# 96   97      66      14     86
# 98   54      80      43     94
# 99   70      92      11     95
#
# [65 rows x 4 columns]
